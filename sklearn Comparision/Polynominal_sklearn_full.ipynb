# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# #### Data Loading

# %%
df=pd.read_csv("../zuu crew scores.csv")
df=df[df['CourseName']=='Foundations of ML']
del df['MemberName'] , df['CourseName']
df.head()
# Out:
#    EducationLevel  Attendance  TotalHours  AssignmentsCompleted  \
# 0               3        79.9        43.7                     2
# 1               2        76.8        95.6                     6
# 2               3        96.6        75.9                     8
# 4               2        83.2        24.0                     6
# 7               3        86.5        88.0                     5
#
#    HackathonParticipation  GitHubScore  PeerReviewScore  CapstoneScore
# 0                       0         62.8              5.0           45.3
# 1                       0         87.4              2.7           78.8
# 2                       0         98.4              2.8           65.4
# 4                       0         41.8              4.2           40.1
# 7                       0         23.9              1.3           68.2

# %%
Y = df['CapstoneScore'].values
X = df.drop(columns=['CapstoneScore']).values

# %% [markdown]
# #### Transform features into polynomial features

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %% [markdown]
# #### Model Train

# %%
model = LinearRegression()
model.fit(X_poly, Y)
# Out:
# LinearRegression()

# %%
# predict value with trained model
Y_hat = model.predict(X_poly)
Y_hat
# Out:
# array([50.13889581, 79.18651268, 67.05580253, 39.22866039, 72.55158351,
#        88.49360972, 39.46136111, 54.76701305, 49.31344962, 44.30841388,
#        60.21198542, 38.69952439, 37.76367672, 55.2306153 , 56.22357434,
#        29.23776611, 79.33278387, 30.60270352, 47.43030336, 77.4020335 ,
#        62.13538805, 40.21197644, 33.70068286, 83.19671167, 77.69636935,
#        33.22611239, 44.79746361, 43.32559043, 48.75819024, 36.17835152,
#        78.03386845, 40.91206194, 27.65829031, 61.71214892, 66.97753162,
#        68.75470986, 35.65715016, 42.29546068, 32.89077629, 62.56861309,
#        58.6187995 , 68.76535407, 58.49628789, 72.93828625, 56.59528103,
#        56.02911367, 52.48081831, 30.1160129 , 61.02350084, 42.82973565,
#        77.4932994 , 40.5114697 , 54.26990017, 75.36283048, 56.65971055,
#        81.13013254, 75.4124048 , 55.50576426, 75.47833976, 68.55729817,
#        27.97137404, 50.7389693 , 43.63950623, 83.00327916, 45.02721696,
#        55.6931587 , 63.36827386, 47.5868934 , 81.92704821, 44.88086176,
#        29.07825024, 59.28311148])

# %% [markdown]
# #### Model Evaluation

# %%
def MSE(Y,Y_hat):
    e_i = Y - Y_hat
    return np.mean(e_i**2)

def MAE(Y,Y_hat):
    e_i = Y - Y_hat
    return np.mean(np.abs(e_i))

def R2_Score(Y,Y_hat):
    y_mean = np.mean(Y)
    e_i = Y - Y_hat
    std_i = Y - y_mean

    E = np.sum(e_i**2) / np.sum(std_i ** 2)
    return 1 - E

def RMSE(Y,Y_hat):
    e_i = Y - Y_hat
    return np.sqrt(np.mean((Y - Y_hat) ** 2))

# %%
mse = MSE(Y, Y_hat)
mae = MAE(Y, Y_hat)
r2 = R2_Score(Y, Y_hat)
rmse = RMSE(Y,Y_hat)

print(f"MSE : {mse}")
print(f"MAE : {mae}")
print(f"R2 Score : {r2}")
print(f"RMSE : {rmse}")
# Out:
# MSE : 15.03336161879424
# MAE : 2.8426874910735838
# R2 Score : 0.9473859107106372
# RMSE : 3.8772879205437194
